# %%
for i in range(3):
    for j in range(1):
        print("*", end=" ")
    print()
# Out:
# *
# *
# *

# %%
i = 1

while i <= 5:
    print(i)
    i += 1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
for i in range(1, 6):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
cnt = 0
while (cnt < 3):
    cnt = cnt + 1
    print("Hello Geek")
# Out:
# Hello Geek
# Hello Geek
# Hello Geek
