# %% [markdown]
# Local Variables

# %%
def greet():
    msg = "Hello from inside the function!"
    print(msg)

greet()
# Out:
# Hello from inside the function!

# %% [markdown]
# creating a local variable inside a function and then trying to access it outside the function, which causes an error.

# %%
def greet():
    msg = "Hello!"
    print("Inside function:", msg)

greet()
print("Outside function:", msg)
# Out:
# Inside function: Hello!
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 6
#       2     msg = "Hello!"
#       3     print("Inside function:", msg)
#       4
#       5 greet()
# ----> 6 print("Outside function:", msg)
#
# NameError: name 'msg' is not defined

# %% [markdown]
# Global Variables

# %%
msg = "Python is awesome!"

def display():
    print("Inside function:", msg)

display()
print("Outside function:", msg)
# Out:
# Inside function: Python is awesome!
# Outside function: Python is awesome!

# %% [markdown]
# Use of Local and Global variables

# %%
def fun():
    s = "Me too."
    print(s)

s = "I love Geeksforgeeks"
fun()   
print(s)
# Out:
# Me too.
# I love Geeksforgeeks

# %% [markdown]
# Modifying Global Variables Inside a Function

# %% [markdown]
# Without global (causes error)

# %%
def fun():
    s += 'GFG'
    print(s)
s = "I Love geeks for geeks"
fun()
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[8], line 5
#       1 def fun():
#       2     s += 'GFG'
#       3     print(s)
#       4 s = "I Love geeks for geeks"
# ----> 5 fun()
#
# Cell In[8], line 2, in fun()
#       1 def fun():
# ----> 2     s += 'GFG'
#       3     print(s)
#
# UnboundLocalError: cannot access local variable 's' where it is not associated with a value

# %% [markdown]
# With global (works correctly)

# %%
s ="Python is great!"
def fun():
    global s
    s += "GFG"
    print(s)
    s="Look for geeks for geeks Python section "
    print(s)
fun()
print(s)
# Out:
# Python is great!GFG
# Look for geeks for geeks Python section
# Look for geeks for geeks Python section

# %% [markdown]
# Global vs Local with Same Name

# %%
a = 1  # Global variable

def f():
    print("f():", a)  # Uses global a

def g():
    a = 2  # Local shadows global
    print("g():", a)

def h():
    global a
    a = 3  # Modifies global a
    print("h():", a)

print("global:", a)
f()
print("global:", a)
g()
print("global:", a)
h()
print("global:", a)
# Out:
# global: 1
# f(): 1
# global: 1
# g(): 2
# global: 1
# h(): 3
# global: 3
